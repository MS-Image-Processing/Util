# %%
import imageio.v3 as io
import matplotlib.pyplot as plt

# %%
from converters import color_to_grayscale
from histogram import threshold
from filtering import konv, gaussian

# %%
img = io.imread("test.jpg")
plt.imshow(img)

# %%
grayscale = color_to_grayscale(img)
plt.imshow(grayscale, cmap="gray")

# %%
segmented = threshold(grayscale, 50, "BINARY")
plt.imshow(segmented, cmap="gray")

# %%
plt.imshow(grayscale, cmap="gray")

# %%
blur_filter = gaussian(5,2)
print("Gaussian filter: ", blur_filter)
fitered = konv(grayscale, blur_filter, )
plt.imshow(fitered, cmap="gray")
# Out:
# Gaussian filter:  [[0.01464488 0.02130818 0.02414533 0.02130818 0.01464488]
#  [0.02130818 0.03100322 0.03513125 0.03100322 0.02130818]
#  [0.02414533 0.03513125 0.03980892 0.03513125 0.02414533]
#  [0.02130818 0.03100322 0.03513125 0.03100322 0.02130818]
#  [0.01464488 0.02130818 0.02414533 0.02130818 0.01464488]]
